# %% [markdown]
# # 台灣銀行牌告匯率爬蟲練習
# ## 範例1： 練習爬取台幣對其他貨幣匯率資料

# %%
import requests
from bs4 import BeautifulSoup
from datetime import datetime
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### 進入台灣銀行牌告匯率網頁：https://rate.bot.com.tw/xrt?Lang=zh-TW ，擷取當日台幣對美金的匯率資訊

# %%
# 進入台灣銀行牌告匯率網頁，查看當日匯率資料
url = "https://rate.bot.com.tw/xrt?Lang=zh-TW"
resp = requests.get(url,verify = False)
resp.encoding = 'utf-8'
# print(resp.text)  # 如有需要，列印出網頁原始碼

soup = BeautifulSoup(resp.text, "lxml")
table = soup.find('table')#, attr = {"class_":"visible-phone print_hide"})
table1 = table.find('tbody')#, attr = {"data-table":"幣別"})
#print(table1.text)
currecy0 = table1.find_all('tr')#.find_all('div')#,attr={"class_":"visible-phone print_hide"})

for currecy in currecy0:
    print(currecy.find('div', attrs={'class':'visible-phone print_hide'}).text.replace(" ",""))#.find_all('div',attr={"class_":"visible-phone print_hide"}))
    money = currecy.find_all('td', attrs={"class":"rate-content-cash text-right print_hide"})
    print("本行現金買入: ",money[0].text)
    print("本行現金賣出: ",money[1].text)
    print('=========================')
# Out:
# D:\anaconda3\lib\site-packages\urllib3\connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# 美金(USD)
#
# 本行現金買入:  29.795
# 本行現金賣出:  30.465
# ...
#
# 港幣(HKD)
#
# 本行現金買入:  3.719
# 本行現金賣出:  3.923
# ...
#
# 英鎊(GBP)
#
# 本行現金買入:  39.23
# 本行現金賣出:  41.35
# ...
#
# 澳幣(AUD)
#
# 本行現金買入:  20.38
# 本行現金賣出:  21.16
# ...
#
# 加拿大幣(CAD)
#
# 本行現金買入:  22.43
# 本行現金賣出:  23.34
# ...
#
# 新加坡幣(SGD)
#
# 本行現金買入:  21.71
# 本行現金賣出:  22.62
# ...
#
# 瑞士法郎(CHF)
#
# 本行現金買入:  29.85
# 本行現金賣出:  31.05
# ...
#
# 日圓(JPY)
#
# 本行現金買入:  0.2668
# 本行現金賣出:  0.2796
# ...
#
# 南非幣(ZAR)
#
# 本行現金買入:  -
# 本行現金賣出:  -
# ...
#
# 瑞典幣(SEK)
#
# 本行現金買入:  2.83
# 本行現金賣出:  3.35
# ...
#
# 紐元(NZD)
#
# 本行現金買入:  19.44
# 本行現金賣出:  20.29
# ...
#
# 泰幣(THB)
#
# 本行現金買入:  0.876
# 本行現金賣出:  1.064
# ...
#
# 菲國比索(PHP)
#
# 本行現金買入:  0.5233
# 本行現金賣出:  0.6563
# ...
#
# 印尼幣(IDR)
#
# 本行現金買入:  0.00183
# 本行現金賣出:  0.00253
# ...
#
# 歐元(EUR)
#
# 本行現金買入:  32.79
# ...

# %%
# 進入台灣銀行牌告匯率網頁，查看當日匯率資料
url = "https://rate.bot.com.tw/xrt?Lang=zh-TW"
resp = requests.get(url,verify = False)
resp.encoding = 'utf-8'
# print(resp.text)  # 如有需要，列印出網頁原始碼

html = BeautifulSoup(resp.text, "lxml")
rate_table = html.find(name='table', attrs={'title':'牌告匯率'}).find(name='tbody').find_all(name='tr')

# 查詢美金(也就是匯率表的第一個元素)對台幣的匯率
currency = rate_table[0].find(name='div', attrs={'class':'visible-phone print_hide'})
print(currency.get_text().replace(" ", ""))  # 去掉空白

buy_rate = rate_table[0].find(name='td', attrs={'data-table':'本行現金買入'})
sell_rate = rate_table[0].find(name='td', attrs={'data-table':'本行現金賣出'})
print("即時現金買入: %s, 即時現金賣出: %s" % (buy_rate.get_text(), sell_rate.get_text()))
# Out:
# D:\anaconda3\lib\site-packages\urllib3\connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# 美金(USD)
#
# 即時現金買入: 29.795, 即時現金賣出: 30.465

# %% [markdown]
# ### 作業part 1：請參考上面的範例，試著爬取所有貨幣對台幣的匯率

# %%
'''

  Your code here
  
'''
# Out:
# 美金(USD)
#
# 即時現金買入: 30.96, 即時現金賣出: 31.63
#
# 港幣(HKD)
#
# 即時現金買入: 3.842, 即時現金賣出: 4.046
#
# 英鎊(GBP)
#
# 即時現金買入: 36.86, 即時現金賣出: 38.98
#
# 澳幣(AUD)
#
# 即時現金買入: 20.87, 即時現金賣出: 21.65
#
# 加拿大幣(CAD)
#
# 即時現金買入: 23.06, 即時現金賣出: 23.97
#
# 新加坡幣(SGD)
#
# 即時現金買入: 22.08, 即時現金賣出: 22.99
#
# 瑞士法郎(CHF)
#
# 即時現金買入: 31.2, 即時現金賣出: 32.4
#
# 日圓(JPY)
#
# 即時現金買入: 0.2851, 即時現金賣出: 0.2979
#
# 南非幣(ZAR)
#
# 即時現金買入: -, 即時現金賣出: -
#
# 瑞典幣(SEK)
#
# 即時現金買入: 2.86, 即時現金賣出: 3.38
#
# 紐元(NZD)
#
# 即時現金買入: 19.6, 即時現金賣出: 20.45
#
# 泰幣(THB)
#
# 即時現金買入: 0.895, 即時現金賣出: 1.083
#
# 菲國比索(PHP)
#
# 即時現金買入: 0.5265, 即時現金賣出: 0.6595
#
# 印尼幣(IDR)
#
# 即時現金買入: 0.00188, 即時現金賣出: 0.00258
#
# 歐元(EUR)
#
# 即時現金買入: 33.97, 即時現金賣出: 35.31
#
# 韓元(KRW)
#
# 即時現金買入: 0.02433, 即時現金賣出: 0.02823
#
# 越南盾(VND)
#
# 即時現金買入: 0.00098, 即時現金賣出: 0.00148
#
# 馬來幣(MYR)
#
# 即時現金買入: 6.393, 即時現金賣出: 8.037
#
# 人民幣(CNY)
#
# 即時現金買入: 4.342, 即時現金賣出: 4.504

# %% [markdown]
# ## 範例2：爬取一個月的美金對台幣歷史匯率資料，並畫出趨勢圖

# %%
history_rate_link
# Out:
# 'https://rate.bot.com.tw/xrt/history/USD'

# %%
quote_history_url
# Out:
# 'https://rate.bot.com.tw/xrt/quote/2019-08/USD'

# %%
rate_table
# Out:
# [<tr>
#  <td class="currency phone-small-font" data-table="幣別">
#  <div>
#  <div class="sp-div sp-america-div">
#  <img alt="幣別國旗" class="sp-img sp-america-img" src="/Content/images/sprite_lateral.png" title="幣別國旗"/>
#  </div>
#  <br class="visible-phone print_hide"/>
#  <div class="visible-phone print_hide">
#                                  美金 (USD)
#                              </div>
#  <div class="hidden-phone print_show" style="text-indent:30px;">
#                                  美金 (USD)
#                              </div>
#  </div>
#  </td>
#  <td class="rate-content-cash text-right print_hide" data-table="本行現金買入">29.845</td>
#  <td class="rate-content-cash text-right print_hide" data-table="本行現金賣出">30.515</td>
#  <td class="rate-content-sight text-right print_hide" data-hide="phone" data-table="本行即期買入">30.195</td>
#  <td class="rate-content-sight text-right print_hide" data-hide="phone" data-table="本行即期賣出">30.295</td>
# ...

# %%
# 先到牌告匯率首頁，爬取所有貨幣的種類
url = "https://rate.bot.com.tw/xrt?Lang=zh-TW"
resp = requests.get(url,verify = False)
resp.encoding = 'utf-8'
soup = BeautifulSoup(resp.text, "lxml")
# Out:
# D:\anaconda3\lib\site-packages\urllib3\connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)

# %%
currency = []
kindss = soup.find_all('tbody')[0]#,attr={"style":"text-indent:30px;"})
kinds = kindss.find_all('div', attrs={'class':'visible-phone print_hide'})
for kind in kinds:   
    currency.append(kind.text.split("(")[1].split(")")[0])
print(currency)
# Out:
# ['USD', 'HKD', 'GBP', 'AUD', 'CAD', 'SGD', 'CHF', 'JPY', 'ZAR', 'SEK', 'NZD', 'THB', 'PHP', 'IDR', 'EUR', 'KRW', 'VND', 'MYR', 'CNY']

# %%
# 先到牌告匯率首頁，爬取所有貨幣的種類
url = "https://rate.bot.com.tw/xrt?Lang=zh-TW"
resp = requests.get(url,verify = False)
resp.encoding = 'utf-8'
html = BeautifulSoup(resp.text, "lxml")
rate_table = html.find(name='table', attrs={'title':'牌告匯率'}).find(name='tbody').find_all(name='tr')

# 擷取匯率表格，把美金(也就是匯率表的第一個元素)擷取出來，查詢其歷史匯率
currency = rate_table[0].find(name='div', attrs={'class':'visible-phone print_hide'})
print(currency.get_text().replace(" ", ""))  # 貨幣種類

# 針對美金，找到其「歷史匯率」的首頁 
history_link = rate_table[0].find(name='td', attrs={'data-table':'歷史匯率'})
history_rate_link = "https://rate.bot.com.tw" + history_link.a["href"]  # 該貨幣的歷史資料首頁
print(history_rate_link)
#
# 到貨幣歷史匯率網頁，選則該貨幣的「歷史區間」，送出查詢後，觀察其網址變化情形，再試著抓取其歷史匯率資料
#
# 用「quote/年-月」去取代網址內容，就可以連到該貨幣的歷史資料
quote_history_url = history_rate_link.replace("history", "quote/2019-08")
resp = requests.get(quote_history_url,verify = False)
print(quote_history_url)
resp.encoding = 'utf-8'
history = BeautifulSoup(resp.text, "lxml")
history_table = history.find(name='table', attrs={'title':'歷史本行營業時間牌告匯率'}).find(name='tbody').find_all(name='tr')

#
# 擷取到歷史匯率資料後，把資料彙整起來並畫出趨勢圖
#
date_history = list()
history_buy = list()
history_sell = list()

for history_rate in history_table:
    # 擷取日期資料
    date_string = history_rate.a.get_text()
    date = datetime.strptime(date_string, '%Y/%M/%d').strftime('%Y/%M/%d')  # 轉換日期格式
    date_history.append(date)  # 日期歷史資料

    history_ex_rate = history_rate.find_all(name='td', attrs={'class':'rate-content-cash text-right print_table-cell'})
    history_buy.append(float(history_ex_rate[0].get_text()))  # 歷史買入匯率
    history_sell.append(float(history_ex_rate[1].get_text()))  # 歷史賣出匯率

# 將匯率資料建成dataframe形式
HistoryExchangeRate = pd.DataFrame({'date': date_history,
                                    'buy_rate':history_buy,
                                    'sell_rate':history_sell})

HistoryExchangeRate = HistoryExchangeRate.set_index('date')  # 指定日期欄位為datafram的index
HistoryExchangeRate = HistoryExchangeRate.sort_index(ascending=True)

# 畫出歷史匯率軌跡圖
plt.figure(figsize=(10, 8))
HistoryExchangeRate[['buy_rate','sell_rate']].plot()  # x=['date'], y=[['buy_rate','sell_rate']] 
plt.legend(loc="upper left")
plt.show()
# Out:
# D:\anaconda3\lib\site-packages\urllib3\connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# 美金(USD)
#
# https://rate.bot.com.tw/xrt/history/USD
# D:\anaconda3\lib\site-packages\urllib3\connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# https://rate.bot.com.tw/xrt/quote/2019-08/USD

# %% [markdown]
# ### 作業part 2：爬取每種貨幣對台幣的一個月歷史匯率資料，並畫出趨勢圖

# %%
# 先到牌告匯率首頁，爬取所有貨幣的種類
url = "https://rate.bot.com.tw/xrt?Lang=zh-TW"
resp = requests.get(url,verify = False)
resp.encoding = 'utf-8'
html = BeautifulSoup(resp.text, "lxml")
rate_table = html.find(name='table', attrs={'title':'牌告匯率'}).find(name='tbody').find_all(name='tr')

# 擷取匯率表格，把美金(也就是匯率表的第一個元素)擷取出來，查詢其歷史匯率
###currency = rate_table[0].find(name='div', attrs={'class':'visible-phone print_hide'})
###print(currency.get_text().replace(" ", ""))  # 貨幣種類

# 針對美金，找到其「歷史匯率」的首頁 
###history_link = rate_table[0].find(name='td', attrs={'data-table':'歷史匯率'})
###history_rate_link = "https://rate.bot.com.tw" + history_link.a["href"]  # 該貨幣的歷史資料首頁

for coins in rate_table:
    coin_name = coins.find(name='div', attrs={'class':'visible-phone print_hide'})
    print(coin_name.get_text().replace(" ", ""))
    coin_href = coins.find(name='td', attrs={'data-table':'歷史匯率'})
    coin_url = "https://rate.bot.com.tw" + coin_href.a["href"]
    print(coin_url)
#====================================================================
#====================================================================
    quote_history_url = coin_url.replace("history", "quote/2019-08")
    resp = requests.get(quote_history_url,verify = False)
    resp.encoding = 'utf-8'
    history = BeautifulSoup(resp.text, "lxml")
    history_table = history.find(name='table', attrs={'title':'歷史本行營業時間牌告匯率'}).find(name='tbody').find_all(name='tr')
    
    #
    # 擷取到歷史匯率資料後，把資料彙整起來並畫出趨勢圖
    #
    date_history = list()
    history_buy = list()
    history_sell = list()
    
    for history_rate in history_table:
        # 擷取日期資料
        date_string = history_rate.a.get_text()
        date = datetime.strptime(date_string, '%Y/%M/%d').strftime('%Y/%M/%d')  # 轉換日期格式
        date_history.append(date)  # 日期歷史資料
    
        history_ex_rate = history_rate.find_all(name='td', attrs={'class':'rate-content-cash text-right print_table-cell'})
        history_buy.append(float(history_ex_rate[0].get_text()))  # 歷史買入匯率
        history_sell.append(float(history_ex_rate[1].get_text()))  # 歷史賣出匯率
    
    # 將匯率資料建成dataframe形式
    HistoryExchangeRate = pd.DataFrame({'date': date_history,
                                        'buy_rate':history_buy,
                                        'sell_rate':history_sell})
    
    HistoryExchangeRate = HistoryExchangeRate.set_index('date')  # 指定日期欄位為datafram的index
    HistoryExchangeRate = HistoryExchangeRate.sort_index(ascending=True)

    # 畫出歷史匯率軌跡圖
    plt.figure(figsize=(10, 8))
    HistoryExchangeRate[['buy_rate','sell_rate']].plot()  # x=['date'], y=[['buy_rate','sell_rate']] 
    plt.legend(loc="upper left")
    plt.show()
# Out:
# D:\anaconda3\lib\site-packages\urllib3\connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# D:\anaconda3\lib\site-packages\urllib3\connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# 美金(USD)
#
# https://rate.bot.com.tw/xrt/history/USD
# 港幣(HKD)
#
# https://rate.bot.com.tw/xrt/history/HKD
# D:\anaconda3\lib\site-packages\urllib3\connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# 英鎊(GBP)
#
# ...

# %%
'''

  Your code here

'''
# Out:
# 美金(USD)
# 港幣(HKD)
# 英鎊(GBP)
# 澳幣(AUD)
# 加拿大幣(CAD)
# 新加坡幣(SGD)
# 瑞士法郎(CHF)
# 日圓(JPY)
# 南非幣(ZAR)
# 瑞典幣(SEK)
# 紐元(NZD)
# 泰幣(THB)
# 菲國比索(PHP)
# 印尼幣(IDR)
# 歐元(EUR)
# 韓元(KRW)
# 越南盾(VND)
# 馬來幣(MYR)
# 人民幣(CNY)
