# %% [markdown]
# # 反爬：驗證碼處理
#
# * 了解「驗證碼機制」的反爬蟲機制
# * 「驗證碼機制」反爬蟲的因應策略

# %% [markdown]
# ## 作業目標
#
# * 讀讀看「test」資料夾下的圖檔！
# * 像 test/test2.png 這種複雜的圖片怎麼辦？

# %% [markdown]
# ### 讀讀看「test」資料夾下的圖檔！

# %%
import requests
import pytesseract
from PIL import Image
from io import BytesIO

# %%
'''
Your Code
'''
img = Image.open("test1.png")
code = pytesseract.image_to_string(img)
print(code)
# Out:
# 619121

# %% [markdown]
# ### 像 test/test2.png 這種複雜的圖片怎麼辦？

# %%
img = Image.open("test2.png")
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=154x64 at 0x1EB4DEF72E8>

# %%
'''
Your Code
'''
img = Image.open("test2.png")
code = pytesseract.image_to_string(img)
print(code)
# Out:
# 14i3

# %%
img = Image.open("test2.png").convert("L")
img
# Out:
# <PIL.Image.Image image mode=L size=154x64 at 0x1EB4DE88E48>

# %%
img = Image.open("test2.png").convert("L")
code = pytesseract.image_to_string(img)
print(code)
# Out:
# 1413
