# %% [markdown]
# # Python 下載XML檔案與解析
#
#
# * 了解 xml 檔案格式與內容
# * 能夠利用套件存取 xml 格式的檔案

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「File I/O」與「xmltodict」讀出來的內容有什麼差異
#
# * 根據範例檔案的結果：
#     1. 請問高雄市有多少地區有溫度資料？
#     2. 請取出每一個地區所記錄的第一個時間點跟溫度
#     3. 請取出第一個地區所記錄的每一個時間點跟溫度

# %% [markdown]
# ### 比較一下範例檔案中的「File I/O」與「xmltodict」讀出來的內容有什麼差異

# %%
'''
Your Code
'''
import os 
dirs = os.listdir("./data")
file = open("./data/64_72hr_CH.xml", "r", encoding='utf-8')
print(file.readlines()[0:5])
# Out:
# ['<?xml version="1.0" encoding="utf-8"?>\n', '<cwbopendata xmlns="urn:cwb:gov:tw:cwbcommon:0.1">\n', '  <identifier>ee2e9d7d-647c-4634-9027-7c822bde7bc0</identifier>\n', '  <sender>weather@cwb.gov.tw</sender>\n', '  <sent>2019-06-28T12:20:35+08:00</sent>\n']

# %% [markdown]
# ### 根據範例檔案的結果：
#
# 1. 請問高雄市有多少地區有溫度資料？
# 2. 請取出每一個地區所記錄的第一個時間點跟溫度
# 3. 請取出第一個地區所記錄的每一個時間點跟溫度

# %%
import xmltodict
#File I/O : 將文件資料全部讀出來
with open("./Data/64_72hr_CH.xml", "r", encoding="utf-8") as file:
        xml = file.read()
        #print(xml)

# %%
# 1. 請問高雄市有多少地區有溫度資料？

'''
Your Code
'''

import xmltodict
with open("./Data/64_72hr_CH.xml", "r", encoding="utf-8") as file:
    xml = file.read()
    dic = dict(xmltodict.parse(xml))
    
    kao = dic['cwbopendata']['dataset']['locations']['location']
    
    
    count1 = 0
    count2 = 0

    for ii in kao:
        wea = ii['weatherElement']
        if wea:
            print(ii['locationName'])
            count2 += 1 

    print(count2)
# Out:
# 鹽埕區
# 鼓山區
# 左營區
# 楠梓區
# 三民區
# 新興區
# 前金區
# 苓雅區
# 前鎮區
# 旗津區
# 小港區
# 鳳山區
# 林園區
# 大寮區
# 大樹區
# 大社區
# 仁武區
# 鳥松區
# 岡山區
# 橋頭區
# 燕巢區
# 田寮區
# 阿蓮區
# 路竹區
# 湖內區
# 茄萣區
# 永安區
# 彌陀區
# 梓官區
# 旗山區
# 美濃區
# 六龜區
# 甲仙區
# 杉林區
# 內門區
# 茂林區
# 桃源區
# 那瑪夏區
# 38

# %%
# 2. 請取出每一個地區所記錄的第一個時間點跟溫度

'''
Your Code
'''
import xmltodict
with open("./Data/64_72hr_CH.xml", "r", encoding="utf-8") as file:
    xml = file.read()
    dic = dict(xmltodict.parse(xml))
    
    kao = dic['cwbopendata']['dataset']['locations']['location']
    for k in kao:
        if k['weatherElement']:
            for item in k['weatherElement']:
                if item['description'] == '溫度':
                    print(k['locationName'],item['time'][0]['dataTime'],item['time'][0]['elementValue']['value'],item['time'][0]['elementValue']['measures'])
# Out:
# 鹽埕區 2019-06-28T12:00:00+08:00 33 攝氏度
# 鼓山區 2019-06-28T12:00:00+08:00 33 攝氏度
# 左營區 2019-06-28T12:00:00+08:00 33 攝氏度
# 楠梓區 2019-06-28T12:00:00+08:00 34 攝氏度
# 三民區 2019-06-28T12:00:00+08:00 32 攝氏度
# 新興區 2019-06-28T12:00:00+08:00 33 攝氏度
# 前金區 2019-06-28T12:00:00+08:00 33 攝氏度
# 苓雅區 2019-06-28T12:00:00+08:00 33 攝氏度
# 前鎮區 2019-06-28T12:00:00+08:00 33 攝氏度
# 旗津區 2019-06-28T12:00:00+08:00 32 攝氏度
# 小港區 2019-06-28T12:00:00+08:00 33 攝氏度
# 鳳山區 2019-06-28T12:00:00+08:00 34 攝氏度
# 林園區 2019-06-28T12:00:00+08:00 33 攝氏度
# 大寮區 2019-06-28T12:00:00+08:00 34 攝氏度
# 大樹區 2019-06-28T12:00:00+08:00 34 攝氏度
# 大社區 2019-06-28T12:00:00+08:00 34 攝氏度
# 仁武區 2019-06-28T12:00:00+08:00 33 攝氏度
# 鳥松區 2019-06-28T12:00:00+08:00 34 攝氏度
# 岡山區 2019-06-28T12:00:00+08:00 34 攝氏度
# 橋頭區 2019-06-28T12:00:00+08:00 35 攝氏度
# 燕巢區 2019-06-28T12:00:00+08:00 34 攝氏度
# 田寮區 2019-06-28T12:00:00+08:00 34 攝氏度
# 阿蓮區 2019-06-28T12:00:00+08:00 34 攝氏度
# 路竹區 2019-06-28T12:00:00+08:00 33 攝氏度
# 湖內區 2019-06-28T12:00:00+08:00 33 攝氏度
# ...

# %%
# 3. 請取出第一個地區所記錄的每一個時間點跟溫度
import xmltodict
with open("./Data/64_72hr_CH.xml", "r", encoding="utf-8") as file:
    xml = file.read()
    dic = dict(xmltodict.parse(xml))
    
    kao = dic['cwbopendata']['dataset']['locations']['location'][0]
    weather = kao['weatherElement'][0]['time']
    for item in weather:
        print (kao['locationName'],item['dataTime'],item['elementValue']['value'],item['elementValue']['measures'])
# Out:
# 鼓山區 2019-06-28T12:00:00+08:00 33 攝氏度
# 鼓山區 2019-06-28T15:00:00+08:00 33 攝氏度
# 鼓山區 2019-06-28T18:00:00+08:00 32 攝氏度
# 鼓山區 2019-06-28T21:00:00+08:00 30 攝氏度
# 鼓山區 2019-06-29T00:00:00+08:00 30 攝氏度
# 鼓山區 2019-06-29T03:00:00+08:00 29 攝氏度
# 鼓山區 2019-06-29T06:00:00+08:00 28 攝氏度
# 鼓山區 2019-06-29T09:00:00+08:00 31 攝氏度
# 鼓山區 2019-06-29T12:00:00+08:00 32 攝氏度
# 鼓山區 2019-06-29T15:00:00+08:00 32 攝氏度
# 鼓山區 2019-06-29T18:00:00+08:00 31 攝氏度
# 鼓山區 2019-06-29T21:00:00+08:00 30 攝氏度
# 鼓山區 2019-06-30T00:00:00+08:00 29 攝氏度
# 鼓山區 2019-06-30T03:00:00+08:00 28 攝氏度
# 鼓山區 2019-06-30T06:00:00+08:00 28 攝氏度
# 鼓山區 2019-06-30T09:00:00+08:00 31 攝氏度
# 鼓山區 2019-06-30T12:00:00+08:00 32 攝氏度
# 鼓山區 2019-06-30T15:00:00+08:00 32 攝氏度
# 鼓山區 2019-06-30T18:00:00+08:00 31 攝氏度
# 鼓山區 2019-06-30T21:00:00+08:00 30 攝氏度
# 鼓山區 2019-07-01T00:00:00+08:00 29 攝氏度
# 鼓山區 2019-07-01T03:00:00+08:00 29 攝氏度
# 鼓山區 2019-07-01T06:00:00+08:00 28 攝氏度
# 鼓山區 2019-07-01T09:00:00+08:00 31 攝氏度

# %%
kk = dic['cwbopendata']['dataset']['locations']['location'][0]
print(kk['locationName'], kk['geocode'])
# Out:
# 鹽埕區 6400100

# %%
dic['cwbopendata']['dataset']['locations']['location'][0]
# Out:
# OrderedDict([('locationName', '鹽埕區'),
#              ('geocode', '6400100'),
#              ('lat', '22.626497'),
#              ('lon', '120.278707'),
#              ('weatherElement',
#               [OrderedDict([('elementName', 'T'),
#                             ('description', '溫度'),
#                             ('time',
#                              [OrderedDict([('dataTime',
#                                             '2019-06-28T12:00:00+08:00'),
#                                            ('elementValue',
#                                             OrderedDict([('value', '33'),
#                                                          ('measures',
#                                                           '攝氏度')]))]),
#                               OrderedDict([('dataTime',
#                                             '2019-06-28T15:00:00+08:00'),
#                                            ('elementValue',
# ...

# %%
kao = dic['cwbopendata']['dataset']['locations']['location'][0]['weatherElement'][0]['time']

# %%
kk = dic['cwbopendata']['dataset']['locations']['location'][0]

print(kk['weatherElement'][0]['elementName'])
print(kk['weatherElement'][0]['description'])
print(kk['weatherElement'][1]['elementName'])
print(kk['weatherElement'][1]['description'])
# Out:
# T
# 溫度
# Td
# 露點溫度

# %%
kk = dic['cwbopendata']['dataset']['locations']['location'][0]['weatherElement']
for i in kk:
    print(i['elementName'])
    print(i['description'])
# Out:
# T
# 溫度
# Td
# 露點溫度
# RH
# 相對濕度
# PoP6h
# 6小時降雨機率
# PoP12h
# 12小時降雨機率
# WD
# 風向
# WS
# 風速
# CI
# 舒適度指數
# AT
# 體感溫度
# Wx
# 天氣現象
# WeatherDescription
# 天氣預報綜合描述

# %%
### time
dic['cwbopendata']['dataset']['locations']['location'][0]['weatherElement'][0]['time'][0]['dataTime']
# Out:
# '2019-06-28T12:00:00+08:00'

# %%
kk = dic['cwbopendata']['dataset']['locations']['location'][0]['weatherElement'][0]['time']
for i in kk:
    print(i['dataTime'])
# Out:
# 2019-06-28T12:00:00+08:00
# 2019-06-28T15:00:00+08:00
# 2019-06-28T18:00:00+08:00
# 2019-06-28T21:00:00+08:00
# 2019-06-29T00:00:00+08:00
# 2019-06-29T03:00:00+08:00
# 2019-06-29T06:00:00+08:00
# 2019-06-29T09:00:00+08:00
# 2019-06-29T12:00:00+08:00
# 2019-06-29T15:00:00+08:00
# 2019-06-29T18:00:00+08:00
# 2019-06-29T21:00:00+08:00
# 2019-06-30T00:00:00+08:00
# 2019-06-30T03:00:00+08:00
# 2019-06-30T06:00:00+08:00
# 2019-06-30T09:00:00+08:00
# 2019-06-30T12:00:00+08:00
# 2019-06-30T15:00:00+08:00
# 2019-06-30T18:00:00+08:00
# 2019-06-30T21:00:00+08:00
# 2019-07-01T00:00:00+08:00
# 2019-07-01T03:00:00+08:00
# 2019-07-01T06:00:00+08:00
# 2019-07-01T09:00:00+08:00

# %%
dic['cwbopendata']['dataset']['locations']['location'][0]['weatherElement'][0]['time'][0]['elementValue']['value']
# Out:
# '33'

# %%
dic['cwbopendata']['dataset']['locations']['location'][0]['weatherElement'][0]['time'][0]['elementValue']['measures']
# Out:
# '攝氏度'
