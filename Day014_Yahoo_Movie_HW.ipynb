# Movie: 一首搖滾上月球, ID: 4887
# Movie: 錢不夠用2, ID: 3026

# %% [markdown]
# ### 指定你有興趣的電影其ID，然後查詢其放映地區資訊。

# %%
# 參考前一個步驟中擷取到的ID資訊，並指定ID
movie_id = 9597

# %%
url = 'https://movies.yahoo.com.tw/api/v1/areas_by_movie_theater'
payload = {'movie_id':str(movie_id)}

# 模擬一個header
headers = {
    'authority': 'movies.yahoo.com.tw',
    'method': 'GET',
    'path': '/api/v1/areas_by_movie_theater?movie_id=' + str(movie_id),
    'scheme': 'https',
    'accept': 'application/json, text/javascript, */*; q=0.01',
    'accept-encoding': 'gzip, deflate, br',
    'accept-language': 'zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7,zh-CN;q=0.6',
    'cookie': 'rxx=9s3x2fws06.1g16irnc&v=1; _ga=GA1.3.2056742944.1551651301; GUC=AQEBAQFczFpdm0IfmwSB&s=AQAAACoo4N5D&g=XMsVBw; BX=4hkdk1decm57t&b=3&s=mr; _ga=GA1.4.2056742944.1551651301; nexagesuid=82843256dd234e8e91aa73f2062f8218; browsed_movie=; avi=eyJpdiI6Im1NeWFJRlVRWDR1endEcGRGUGJUbVE9PSIsInZhbHVlIjoickRpU3JuUytmcGl6cjF5OW0rNU9iZz09IiwibWFjIjoiY2VmY2NkNzZmM2NhNjY5YzlkOTcyNjE5OGEyMzU0NWYxOTdmMDRkMDY3OWNmMmZjOTMxYjc5MjI5N2Q5NGE5MiJ9; cmp=t=1559391030&j=0; _gid=GA1.4.779543841.1559391031; XSRF-TOKEN=%3D; m_s=; _gat=1; nexagesd=10',
    'dnt': '1',
    'mv-authorization': '21835b082e15b91a69b3851eec7b31b82ce82afb',
    'referer': 'https://movies.yahoo.com.tw/',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.169 Safari/537.36',
    'x-requested-with': 'XMLHttpRequest',
}
    
resp = requests.get(url, params=payload, headers=headers)
#print(resp.json())  # 若有需要，列印出json原始碼

# 這裡回傳的格式是JSON格式的資料，要解析JSON擷取資料
for p in resp.json():
    print('放映地區: {0}, 代號(area_id): {1}'.format(p['title'], p['area_id']))
# Out:
# 放映地區: 台北市, 代號(area_id): 28
# 放映地區: 新北市, 代號(area_id): 8
# 放映地區: 桃園, 代號(area_id): 16
# 放映地區: 新竹, 代號(area_id): 20
# 放映地區: 苗栗, 代號(area_id): 15
# 放映地區: 台中, 代號(area_id): 2
# 放映地區: 彰化, 代號(area_id): 22
# 放映地區: 南投, 代號(area_id): 13
# 放映地區: 雲林, 代號(area_id): 19
# 放映地區: 嘉義, 代號(area_id): 21
# 放映地區: 台南, 代號(area_id): 10
# 放映地區: 高雄, 代號(area_id): 17
# 放映地區: 屏東, 代號(area_id): 14
# 放映地區: 基隆, 代號(area_id): 18
# 放映地區: 宜蘭, 代號(area_id): 11
# 放映地區: 花蓮, 代號(area_id): 12
# 放映地區: 台東, 代號(area_id): 9
# 放映地區: 金門, 代號(area_id): 24
# 放映地區: 澎湖, 代號(area_id): 23

# %% [markdown]
# ### 指定你想要觀看的放映地區，查詢有上映電影的場次日期

# %%
# 指定放映地區
area_id = 28

# %%
# 向網站發送請求
url = 'https://movies.yahoo.com.tw/movietime_result.html'
payload = {'movie_id':str(movie_id), 'area_id':str(area_id)}
resp = requests.get(url, params=payload)
resp.encoding = 'utf-8'

soup = BeautifulSoup(resp.text, 'lxml')
movie_date = soup.find_all("label", attrs={'for':re.compile("date_[\d]")})

# 列印播放日期
for date in movie_date:
    print("%s %s" % (date.p.string, date.h3.string))
# Out:
# 十二月 12
# 十二月 13
# 十二月 14
# 十二月 15
# 十二月 16

# %% [markdown]
# ### 最後指定觀看的日期，查詢並列印出放映的電影院、放映類型(數位、3D、IMAX 3D...)、放映時間等資訊。

# %%
# 選定要觀看的日期
date = "2019-12-12"
movie_id = 9597

# %%
# 向網站發送請求，獲取上映的電影院及時間資訊
url = "https://movies.yahoo.com.tw/ajax/pc/get_schedule_by_movie"
payload = {'movie_id':str(movie_id),
           'date':date,
           'area_id':str(area_id),
           'theater_id':'',
           'datetime':'',
           'movie_type_id':''}

resp = requests.get(url, params=payload)
#print(resp.json()['view'])  # 若有需要，列印出json原始碼

soup = BeautifulSoup(resp.json()['view'], 'lxml')
detail = soup.find("ul", attrs={'class':'area_time _c jq_area_time'})

# %%
box = soup.find_all("ul", attrs={'class':'area_time _c jq_area_time'})
for i in box:
    theater = i.find("a").text
    type_ = i.find("span", attrs={'class':"tapR"}).text
    print(theater, type_)
    time_ = detail.find_all("label", attrs={'class':""})
    for ii in time_ :
        print(ii.text)
    print('===========================================')
# Out:
# 國賓影城(台北長春廣場) 數位
# 11:30
# 13:30
# 15:30
# 13:05
# ===========================================
# 欣欣秀泰影城 數位
# 11:30
# 13:30
# 15:30
# 13:05
# ===========================================
# 台北美麗華大直影城 數位
# 11:30
# 13:30
# 15:30
# 13:05
# ===========================================
# 華威天母影城 數位
# 11:30
# 13:30
# 15:30
# 13:05
# ===========================================
# 台北新光影城 數位
# 11:30
# 13:30
# 15:30
# 13:05
# ===========================================
# 台北in89豪華數位影城 數位
# 11:30
# 13:30
# 15:30
# 13:05
# ===========================================
# 國賓大戲院(西門) 數位
# 11:30
# 13:30
# 15:30
# 13:05
# ===========================================
# 台北樂聲影城 數位
# 11:30
# 13:30
# 15:30
# 13:05
# ===========================================
# 台北日新威秀影城 數位
# 11:30
# 13:30
# 15:30
# 13:05
# ===========================================
# 喜滿客絕色影城 數位
# 11:30
# 13:30
# 15:30
# 13:05
# ===========================================
# 台北信義威秀影城 數位
# 11:30
# 13:30
# 15:30
# 13:05
# ===========================================
# 國賓影城(微風廣場) 數位
# 11:30
# 13:30
# 15:30
# 13:05
# ===========================================
# 哈拉影城
# 11:30
# 13:30
# 15:30
# 13:05
# ===========================================
# 百老匯數位影城 數位
# 11:30
# 13:30
# 15:30
# 13:05
# ===========================================
# 東南亞秀泰影城 數位
# 11:30
# 13:30
# 15:30
# 13:05
# ===========================================
# 今日秀泰影城 數位
# 11:30
# 13:30
# 15:30
# 13:05
# ===========================================
# 京站威秀影城 數位
# 11:30
# 13:30
# 15:30
# 13:05
# ===========================================
# 梅花數位影院 數位
# 11:30
# 13:30
# 15:30
# 13:05
# ===========================================
# 台北新民生戲院 數位
# 11:30
# 13:30
# 15:30
# 13:05
# ===========================================
# 誠品電影院 數位
# 11:30
# 13:30
# 15:30
# 13:05
# ===========================================
# 喜樂時代影城南港店 數位
# 11:30
# 13:30
# 15:30
# 13:05
# ===========================================
# 美麗新大直皇家影城 數位
# 11:30
# 13:30
# 15:30
# 13:05
# ===========================================

# %%
# Out:
# 11:30
# 13:30
# 15:30
# 13:05

# %%
detail = soup.find("ul", attrs={'class':'area_time _c jq_area_time'})
print(detail)
# Out:
# <ul class="area_time _c jq_area_time" data-theater_name="國賓影城(台北長春廣場)" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=29" data-theater_url="http://www.ambassador.com.tw/" id="theater_id_29">
# <li class="adds">
# <a href="https://movies.yahoo.com.tw/theater_result.html/id=29">國賓影城(台北長春廣場)</a>
# <span>02-25155755</span>
# </li>
# <li class="taps">
# <span class="tapR">數位</span> </li>
# <li class="time _c">
# <div class="input_picker jq_input_picker">
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '冰雪奇緣2']" data-movie_date="12.12" data-movie_time="11:30" data-movie_title="冰雪奇緣2" data-movie_type="數位" data-news="news" id="72572828" name="schedule_list" type="radio" value="2019-12-12 11:30:00"/>
# <label class="" for="72572828">11:30</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '冰雪奇緣2']" data-movie_date="12.12" data-movie_time="13:30" data-movie_title="冰雪奇緣2" data-movie_type="數位" data-news="news" id="72572829" name="schedule_list" type="radio" value="2019-12-12 13:30:00"/>
# <label class="" for="72572829">13:30</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '冰雪奇緣2']" data-movie_date="12.12" data-movie_time="15:30" data-movie_title="冰雪奇緣2" data-movie_type="數位" data-news="news" id="72572830" name="schedule_list" type="radio" value="2019-12-12 15:30:00"/>
# <label class="" for="72572830">15:30</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '冰雪奇緣2']" data-movie_date="12.12" data-movie_time="18:10" data-movie_title="冰雪奇緣2" data-movie_type="數位" data-news="news" id="72572831" name="schedule_list" type="radio" value="2019-12-12 18:10:00"/>
# <label class="select" for="72572831">18:10</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '冰雪奇緣2']" data-movie_date="12.12" data-movie_time="20:10" data-movie_title="冰雪奇緣2" data-movie_type="數位" data-news="news" id="72572832" name="schedule_list" type="radio" value="2019-12-12 20:10:00"/>
# <label class="select" for="72572832">20:10</label>
# </div>
# </li>
# <li class="taps">
# <span class="tapR">數位</span> <span class="tapB">中文</span> </li>
# <li class="time _c">
# <div class="input_picker jq_input_picker">
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '冰雪奇緣2']" data-movie_date="12.12" data-movie_time="13:05" data-movie_title="冰雪奇緣2" data-movie_type="數位" data-news="news" id="72572833" name="schedule_list" type="radio" value="2019-12-12 13:05:00"/>
# <label class="" for="72572833">13:05</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '冰雪奇緣2']" data-movie_date="12.12" data-movie_time="17:20" data-movie_title="冰雪奇緣2" data-movie_type="數位" data-news="news" id="72572834" name="schedule_list" type="radio" value="2019-12-12 17:20:00"/>
# <label class="select" for="72572834">17:20</label>
# </div>
# </li>
# </ul>

# %%
test = soup.find_all("a")
str(test).split('>')[1::2]
# Out:
# ['國賓影城(台北長春廣場)</a',
#  '欣欣秀泰影城</a',
#  '台北美麗華大直影城</a',
#  '華威天母影城</a',
#  '台北新光影城</a',
#  '台北in89豪華數位影城</a',
#  '國賓大戲院(西門)</a',
#  '台北樂聲影城</a',
#  '台北日新威秀影城</a',
#  '喜滿客絕色影城</a',
#  '台北信義威秀影城</a',
#  '國賓影城(微風廣場)</a',
#  '哈拉影城</a',
#  '百老匯數位影城</a',
#  '東南亞秀泰影城</a',
#  '今日秀泰影城</a',
#  '京站威秀影城</a',
#  '梅花數位影院</a',
#  '台北新民生戲院</a',
#  '誠品電影院</a',
#  '喜樂時代影城南港店</a',
#  '美麗新大直皇家影城</a',
#  '全部電影場次</a',
#  '官網訂票</a',
#  '官網訂票</a']

# %%
print(html)
# Out:
# <select class="movie_name" id="sbox_mid" name="movie_id">
# <option value="">請選擇片名</option>
# <option data-name="特約經紀公司" value="10364">特約經紀公司</option>
# <option data-name="一屍到底番外篇：好萊塢大作戰！" value="10352">一屍到底番外篇：好萊塢大作戰！</option>
# <option data-name="餓魔餐廳" value="10342">餓魔餐廳</option>
# <option data-name="花生醬獵鷹的願望" value="10340">花生醬獵鷹的願望</option>
# <option data-name="女孩要革命" value="10339">女孩要革命</option>
# <option data-name="我的靈魂是愛做的" value="10336">我的靈魂是愛做的</option>
# <option data-name="絕世情歌" value="10328">絕世情歌</option>
# <option data-name="人間失格：太宰治與他的3個女人" value="10287">人間失格：太宰治與他的3個女人</option>
# <option data-name="抓狂博物館" value="10279">抓狂博物館</option>
# <option data-name="呆萌特務" value="10264">呆萌特務</option>
# <option data-name="去年聖誕節" value="10256">去年聖誕節</option>
# <option data-name="野蠻遊戲：全面晉級" value="10134">野蠻遊戲：全面晉級</option>
# <option data-name="布紐爾超現實人生" value="10334">布紐爾超現實人生</option>
# <option data-name="夕霧花園" value="10327">夕霧花園</option>
# <option data-name="寂寞診療室" value="10282">寂寞診療室</option>
# <option data-name="懸案密碼前傳：瓶中信" value="10254">懸案密碼前傳：瓶中信</option>
# <option data-name="布魯克林孤兒" value="10224">布魯克林孤兒</option>
# <option data-name="暴走曼哈頓" value="10044">暴走曼哈頓</option>
# <option data-name="鋒迴路轉" value="10258">鋒迴路轉</option>
# <option data-name="賽道狂人" value="10097">賽道狂人</option>
# <option data-name="麂皮：永不滿足" value="10358">麂皮：永不滿足</option>
# <option data-name="82年生的金智英" value="10298">82年生的金智英</option>
# <option data-name="許怨房" value="10294">許怨房</option>
# <option data-name="BanG Dream！ FILM LIVE" value="10271">BanG Dream！ FILM LIVE</option>
# <option data-name="冰雪奇緣2" value="9597">冰雪奇緣2</option>
# <option data-name="催眠．裁決" value="10322">催眠．裁決</option>
# <option data-name="抱歉我們錯過你了" value="10309">抱歉我們錯過你了</option>
# <option data-name="Hello World" value="10302">Hello World</option>
# <option data-name="大餓" value="10296">大餓</option>
# <option data-name="萬萬沒想到" value="10281">萬萬沒想到</option>
# <option data-name="神機有毛病" value="10260">神機有毛病</option>
# <option data-name="為美好的世界獻上祝福！紅傳說" value="10226">為美好的世界獻上祝福！紅傳說</option>
# <option data-name="樂園" value="10280">樂園</option>
# <option data-name="決戰中途島" value="10130">決戰中途島</option>
# <option data-name="安眠醫生" value="10098">安眠醫生</option>
# <option data-name="地久天長" value="9621">地久天長</option>
# <option data-name="魔鬼終結者：黑暗宿命" value="10067">魔鬼終結者：黑暗宿命</option>
# <option data-name="紫羅蘭永恆花園外傳－永遠與自動手記人偶－" value="10292">紫羅蘭永恆花園外傳－永遠與自動手記人偶－</option>
# <option data-name="陽光普照" value="10240">陽光普照</option>
# <option data-name="阿達一族" value="9992">阿達一族</option>
# <option data-name="狙擊獵殺：救援行動" value="10284">狙擊獵殺：救援行動</option>
# <option data-name="雙子殺手" value="10017">雙子殺手</option>
# <option data-name="盲人律師" value="10267">盲人律師</option>
# <option data-name="黑魔女2" value="10262">黑魔女2</option>
# <option data-name="電影版 壞傢伙們" value="10249">電影版 壞傢伙們</option>
# <option data-name="藍波：最後一滴血" value="10205">藍波：最後一滴血</option>
# <option data-name="屍樂園：髒比雙拼" value="10176">屍樂園：髒比雙拼</option>
# <option data-name="弒婚遊戲" value="10171">弒婚遊戲</option>
# <option data-name="108悍將" value="10238">108悍將</option>
# <option data-name="小丑" value="9949">小丑</option>
# <option data-name="瞞天機密" value="10206">瞞天機密</option>
# <option data-name="校外打怪教學" value="10200">校外打怪教學</option>
# <option data-name="信用詐欺師JP" value="10190">信用詐欺師JP</option>
# <option data-name="無間行動" value="10155">無間行動</option>
# <option data-name="星際救援" value="10227">星際救援</option>
# <option data-name="返校" value="10109">返校</option>
# <option data-name="今天也要用便當出擊" value="10223">今天也要用便當出擊</option>
# <option data-name="花椒之味" value="10158">花椒之味</option>
# <option data-name="我家有個開心農場" value="10145">我家有個開心農場</option>
# <option data-name="好小男孩" value="9894">好小男孩</option>
# <option data-name="牠 第二章" value="10042">牠 第二章</option>
# <option data-name="極限逃生" value="10174">極限逃生</option>
# <option data-name="雙面特務" value="10163">雙面特務</option>
# <option data-name="你願意嫁給我老公嗎？" value="10141">你願意嫁給我老公嗎？</option>
# <option data-name="第九分局" value="10099">第九分局</option>
# <option data-name="下半場" value="9807">下半場</option>
# <option data-name="全面攻佔3：天使救援" value="10082">全面攻佔3：天使救援</option>
# <option data-name="普羅米亞" value="10119">普羅米亞</option>
# <option data-name="驅魔使者" value="10095">驅魔使者</option>
# <option data-name="憤怒鳥玩電影2：冰的啦" value="10002">憤怒鳥玩電影2：冰的啦</option>
# <option data-name="玩命關頭：特別行動" value="9582">玩命關頭：特別行動</option>
# <option data-name="獅子王" value="9116">獅子王</option>
# <option data-name="玩具總動員4" value="9924">玩具總動員4</option>
# <option data-name="毀滅者" value="9405">毀滅者</option>
# <option data-name="庫爾斯克號：深海救援" value="9134">庫爾斯克號：深海救援</option>
# <option data-name="厄夜追緝令" value="9589">厄夜追緝令</option>
# <option data-name="苦兒流浪記" value="9538">苦兒流浪記</option>
# <option data-name="活個精彩" value="9394">活個精彩</option>
# <option data-name="限時好友" value="9578">限時好友</option>
# <option data-name="祝你忌日快樂" value="9568">祝你忌日快樂</option>
# <option data-name="艾莉塔：戰鬥天使" value="8553">艾莉塔：戰鬥天使</option>
# <option data-name="馴龍高手3" value="8350">馴龍高手3</option>
# <option data-name="幸福綠皮書" value="9150">幸福綠皮書</option>
# <option data-name="貝士浮生錄" value="6906">貝士浮生錄</option>
# <option data-name="一首搖滾上月球" value="4887">一首搖滾上月球</option>
# <option data-name="錢不夠用2" value="3026">錢不夠用2</option>
# </select>

# %%
'''

  試著從上一步驟回傳的電影院資料中，擷取電影院名稱、影片放映類型以及時間表
  
  Your code here.

'''
# Out:
# ----------------------------------------------------------------------
# 電影院:  台北美麗華大直影城
# 放映類型:  數位
# 2019-08-21 09:00:00
# 2019-08-21 11:10:00
# 2019-08-21 13:15:00
# 2019-08-21 15:20:00
# 2019-08-21 19:30:00
# 2019-08-21 21:40:00
# 2019-08-21 22:30:00
# ----------------------------------------------------------------------
# 電影院:  台北新光影城
# 放映類型:  數位
# 2019-08-21 10:00:00
# 2019-08-21 14:50:00
# 2019-08-21 19:30:00
# ----------------------------------------------------------------------
# 電影院:  台北in89豪華數位影城
# 放映類型:  數位
# 2019-08-21 09:30:00
# 2019-08-21 11:20:00
# 2019-08-21 13:15:00
# 2019-08-21 15:10:00
# 2019-08-21 16:10:00
# 2019-08-21 17:10:00
# 2019-08-21 18:05:00
# 2019-08-21 19:10:00
# 2019-08-21 21:10:00
# 2019-08-21 23:10:00
# 2019-08-22 01:10:00
# ----------------------------------------------------------------------
# 電影院:  台北日新威秀影城
# 放映類型:  數位
# 2019-08-21 09:00:00
# 2019-08-21 10:55:00
# 2019-08-21 12:50:00
# 2019-08-21 14:45:00
# 2019-08-21 16:40:00
# 2019-08-21 18:35:00
# 2019-08-21 20:35:00
# ----------------------------------------------------------------------
# 電影院:  喜滿客絕色影城
# 放映類型:  數位
# 2019-08-21 10:00:00
# 2019-08-21 11:55:00
# 2019-08-21 13:50:00
# 2019-08-21 15:45:00
# 2019-08-21 17:40:00
# 2019-08-21 19:35:00
# 2019-08-21 21:30:00
# ----------------------------------------------------------------------
# 電影院:  台北信義威秀影城
# 放映類型:  數位
# 2019-08-21 09:00:00
# 2019-08-21 11:00:00
# 2019-08-21 13:00:00
# 2019-08-21 15:00:00
# 2019-08-21 17:00:00
# 2019-08-21 19:00:00
# 2019-08-21 21:00:00
# 2019-08-21 23:00:00
# ----------------------------------------------------------------------
# 電影院:  喜滿客京華影城
# 放映類型:  數位
# 2019-08-21 10:30:00
# 2019-08-21 12:30:00
# 2019-08-21 14:30:00
# 2019-08-21 16:30:00
# 2019-08-21 18:30:00
# 2019-08-21 20:30:00
# 2019-08-21 22:30:00
# ----------------------------------------------------------------------
# 電影院:  京站威秀影城
# 放映類型:  數位
# 2019-08-21 09:00:00
# 2019-08-21 11:00:00
# 2019-08-21 13:00:00
# 2019-08-21 15:00:00
# 2019-08-21 17:00:00
# 2019-08-21 19:00:00
# 2019-08-21 21:00:00
# ----------------------------------------------------------------------
# 電影院:  喜樂時代影城南港店
# 放映類型:  數位
# 2019-08-21 10:20:00
# 2019-08-21 11:10:00
# 2019-08-21 12:20:00
# 2019-08-21 13:10:00
# 2019-08-21 14:20:00
# 2019-08-21 15:10:00
# 2019-08-21 16:20:00
# 2019-08-21 17:10:00
# 2019-08-21 18:20:00
# 2019-08-21 19:15:00
# 2019-08-21 20:20:00
# 2019-08-21 21:15:00
# 2019-08-21 22:20:00
